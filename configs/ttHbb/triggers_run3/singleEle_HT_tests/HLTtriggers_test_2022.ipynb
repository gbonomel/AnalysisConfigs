# %%
import coffea
import matplotlib.pyplot as plt
import numpy as np
import mplhep as hep
hep.style.use(hep.style.ROOT)
import os

# %% [markdown]
# # Analyzing coffea output

# %%
from coffea.util import load

# %%
results_dir = "/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask"
df = load(f"{results_dir}/output_TTH_Hto2B_2022_postEE.coffea")

# %%
df["cutflow"]
# Out:
# {'initial': {'TTH_Hto2B_2022_postEE': 10478951},
#  'skim': {'TTH_Hto2B_2022_postEE': 1528179},
#  'presel': {'TTH_Hto2B_2022_postEE': 1528179},
#  'semilep': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 1528179}},
#  'semilep_Ele28': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 719920}},
#  'semilep_Ele30': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 725703}},
#  'semilep_Ele32': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 702902}},
#  'semilep_tripleB_Ele30': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 1067672}},
#  'semilep_tripleB': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 687717}},
#  'semilep_4j': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 1516666}},
#  'semilep_4j_Ele28': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 716962}},
#  'semilep_4j_Ele30': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 722608}},
#  'semilep_4j_Ele32': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 699900}},
#  'semilep_4j_tripleB_Ele30': {'TTH_Hto2B_2022_postEE': {'TTH_Hto2B': 1064068}},
# ...

# %%
cats = list(filter(lambda k: "semilep_recoele15tight" in k , df["cutflow"].keys(), ))
print(cats)

effs = {}
for c in cats[1:]:
    effs[c] = df["sumw"][c]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"] /df["sumw"][cats[0]]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"]  
    
for cat, e in effs.items():
    print(f"{cat.replace('semilep_recoele15tight_','')} --> {e*100:.3f}%")
# Out:
# ['semilep_recoele15tight', 'semilep_recoele15tight_Ele28', 'semilep_recoele15tight_Ele30', 'semilep_recoele15tight_Ele28_or_Ele30', 'semilep_recoele15tight_Ele32', 'semilep_recoele15tight_tripleB_Ele30', 'semilep_recoele15tight_tripleB']
# Ele28 --> 71.944%
# Ele30 --> 72.000%
# Ele28_or_Ele30 --> 74.139%
# Ele32 --> 69.714%
# tripleB_Ele30 --> 83.912%
# tripleB --> 45.943%

# %%
cats[0], cats[1]
# Out:
# ('semilep_recoele15tight', 'semilep_recoele15tight_Ele28')

# %%
cats = list(filter(lambda k: "semilep_recoele30tight" in k , df["cutflow"].keys(), ))
print(cats)
print("base cat", cats[0])
effs = {}
for c in cats[1:]:
    effs[c] = df["sumw"][c]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"] /df["sumw"][cats[0]]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"]  
    
for cat, e in effs.items():
    print(f"{cat.replace('semilep_recoele30tight_','')} --> {e*100:.3f}%")
# Out:
# ['semilep_recoele30tight', 'semilep_recoele30tight_Ele28', 'semilep_recoele30tight_Ele30', 'semilep_recoele30tight_Ele28_or_Ele30', 'semilep_recoele30tight_Ele32', 'semilep_recoele30tight_tripleB_Ele30', 'semilep_recoele30tight_tripleB', 'semilep_recoele30tight3b', 'semilep_recoele30tight3b_Ele28', 'semilep_recoele30tight3b_Ele30', 'semilep_recoele30tight3b_Ele28_or_Ele30', 'semilep_recoele30tight3b_Ele32', 'semilep_recoele30tight3b_tripleB_Ele30', 'semilep_recoele30tight3b_tripleB']
# base cat semilep_recoele30tight
# Ele28 --> 86.305%
# Ele30 --> 88.302%
# Ele28_or_Ele30 --> 88.992%
# Ele32 --> 85.815%
# tripleB_Ele30 --> 93.592%
# tripleB --> 47.041%
# semilep_recoele30tight3b --> 41.264%
# semilep_recoele30tight3b_Ele28 --> 35.801%
# semilep_recoele30tight3b_Ele30 --> 36.418%
# semilep_recoele30tight3b_Ele28_or_Ele30 --> 36.707%
# semilep_recoele30tight3b_Ele32 --> 35.365%
# semilep_recoele30tight3b_tripleB_Ele30 --> 39.961%
# semilep_recoele30tight3b_tripleB --> 31.127%

# %%
cats = list(filter(lambda k: "semilep_recoele30tight3b" in k , df["cutflow"].keys(), ))
print(cats)

effs = {}
for c in cats[1:]:
    effs[c] = df["sumw"][c]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"] /df["sumw"][cats[0]]["TTH_Hto2B_2022_postEE"]["TTH_Hto2B"]  
    
for cat, e in effs.items():
    print(f"{cat.replace('semilep_recoele30tight3b_','')} --> {e*100:.3f}%")
# Out:
# ['semilep_recoele30tight3b', 'semilep_recoele30tight3b_Ele28', 'semilep_recoele30tight3b_Ele30', 'semilep_recoele30tight3b_Ele28_or_Ele30', 'semilep_recoele30tight3b_Ele32', 'semilep_recoele30tight3b_tripleB_Ele30', 'semilep_recoele30tight3b_tripleB']
# Ele28 --> 86.761%
# Ele30 --> 88.257%
# Ele28_or_Ele30 --> 88.957%
# Ele32 --> 85.706%
# tripleB_Ele30 --> 96.843%
# tripleB --> 75.433%

# %%
df["variables"]
# Out:
# {'higgs_pt': defaultdict(dict,
#              {'TTH_Hto2B': {'TTH_Hto2B_2022_postEE': Hist(
# ...

# %%
def hist_comparison_2(Hs, cats, labels, file,  yratio_lim=[0,1],ylog=False, output_folder=None, ):
    # os.makedirs(output_folder, exist_ok=True)
    # os.system(f"cp /eos/user/d/dvalsecc/www/index.php {output_folder}")
    
    fig = plt.figure(figsize=(8,9), dpi=100)
    gs = fig.add_gridspec(nrows=2, ncols=1, hspace=0.05, height_ratios=[0.55,0.45])
    axs = gs.subplots(sharex=True)
    plt.subplots_adjust(wspace=0.3)
    
    axu =  axs[0]
    axd =  axs[1]

    
    for i, (cat, label) in  enumerate(zip(cats, labels)):
        if i == 0:
            hep.histplot(Hs[cat, "nominal", :], label=label, ax=axu, color="black")
        else:
            hep.histplot(Hs[cat, "nominal", :], label=label, ax=axu)
        
    if ylog:
        axu.set_yscale("log")
    axu.legend(fontsize=16)
    axu.set_xlabel('')
    axu.set_ylabel('Events')
    hep.plot.ylow(axu)
    hep.plot.yscale_legend(axu)

    # Ratios
    nom = Hs[cats[0], "nominal",:]
    nomvalues = nom.values()
    nom_sig2 = nom.variances()
    centers = nom.axes[0].centers
    edges = nom.axes[0].edges
    minratio, maxratio = 1000.,0.
    for i,cat in enumerate(cats):
        h = Hs[cat, "nominal",:]
        h_val = h.values()
        h_sig2 = h.variances()
        
        err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
        r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
        m, M = np.min(r), np.max(r)
        if m < minratio: minratio = m
        if M > maxratio: maxratio = M
        
        if i == 0:
            axd.errorbar(centers, r, xerr=0, yerr=err,
                     fmt=".", linestyle='none', elinewidth=1, color="black")
        else:
            axd.errorbar(centers, r, xerr=0, yerr=err,
                     fmt=".", linestyle='none', elinewidth=1)
       
    axd.legend(ncol=3, fontsize='xx-small')
    hep.plot.yscale_legend(axd)
    axd.set_xlabel(nom.axes[0].label)
    axd.set_ylim(*yratio_lim)
    axd.set_ylabel("efficiency")
    axd.grid(which="both",axis="y")
    
    hep.cms.label(rlabel="26.67/fb (13.6 TeV)", loc=0, ax=axu) 
    
    if output_folder: 
        os.makedirs(output_folder, exist_ok=True)
        fig.savefig(f"{output_folder}/{file}.png")
        fig.savefig(f"{output_folder}/{file}.pdf")

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Higgs $p_T$

# %%
hist_comparison_2(df["variables"]["higgs_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30',
                 'semilep_recoele15tight_Ele32',"semilep_recoele15tight_tripleB_Ele30", 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                 #"semilep_recoele15tight_doubleB_looser_Ele30"
                ],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30", "Ele28 | Ele30", "Ele32",
                        "Ele30 | 4jet 3b HT330"],#, "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_higgs_pt", 
                  yratio_lim=[0.6,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["higgs_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele25tight', 'semilep_recoele25tight_Ele28',
                 'semilep_recoele25tight_Ele30', 
                 'semilep_recoele25tight_Ele28_or_Ele30',
                 'semilep_recoele25tight_Ele32',
                 #"semilep_recoele25tight_doubleB_tighter_Ele30",
                #"semilep_recoele25tight_doubleB_looser_Ele30"],
                ],
                 labels=["1 tight ele $p_T>25$", "Ele28_HT150", "Ele30", "Ele28 | Ele30", "Ele32"],
                        #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele25_higgs_pt", 
                  yratio_lim=[0.6,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["higgs_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight',
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30',
                 'semilep_recoele30tight_Ele32',
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                ],
                 labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30", "Ele28 | Ele30", "Ele32"],
                        #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_higgs_pt", 
                  yratio_lim=[0.6,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %% [markdown]
# ### HT

# %%
hist_comparison_2(df["variables"]["HT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30',
                 'semilep_recoele15tight_Ele32',
                 "semilep_recoele15tight_tripleB_Ele30", 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                ],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_lheHT", 
                  yratio_lim=[0.4,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["HT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight', 
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30',
                 'semilep_recoele30tight_Ele32',
                 "semilep_recoele30tight_tripleB_Ele30", 
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                 ],
                  labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_lheHT", 
                  yratio_lim=[0.6,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["recoHT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 'semilep_recoele15tight_Ele28','semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele32',"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30", "Ele32",
                        "Ele30 | 4jet 3b HT330"],#, "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_HT_reco", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["recoHT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30',
                 'semilep_recoele15tight_Ele32',
                 "semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_recoHT", 
                  yratio_lim=[0.25,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["recoHT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele25tight', 'semilep_recoele25tight_Ele28',
                 'semilep_recoele25tight_Ele30', 
                 'semilep_recoele25tight_Ele28_or_Ele30',
                 'semilep_recoele25tight_Ele32'],
                 #"semilep_recoele25tight_doubleB_tighter_Ele30",
                #"semilep_recoele25tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>25$", "Ele28_HT150", "Ele30", "Ele28 | Ele30", "Ele32"],
                        #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoHT_ele25reco", 
                  yratio_lim=[0.3,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["recoHT"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight', 
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30',
                 'semilep_recoele30tight_Ele32',
                 "semilep_recoele30tight_tripleB_Ele30"], 
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_recoHT", 
                  yratio_lim=[0.25,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %% [markdown]
# ### Electron $p_T$

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30',
                 'semilep_recoele15tight_Ele32',
                 "semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_electron_pt", 
                  yratio_lim=[0.4,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight', 
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30',
                 'semilep_recoele30tight_Ele32',
                 "semilep_recoele30tight_tripleB_Ele30"], 
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_electron_pt", 
                  yratio_lim=[0.4,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 'semilep_recoele15tight_Ele28','semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele32',"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>25$", "Ele28_HT150", "Ele30", "Ele32",
                        "Ele30 | 4jet 3b HT330"],# "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_electron_pt", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt2"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30',
                 'semilep_recoele15tight_Ele32',
                 "semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_electron_pt2", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt2"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 'semilep_recoele15tight_Ele28','semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele32',"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>25$", "Ele28_HT150", "Ele30", "Ele32",
                        "Ele30 | 4jet 3b HT330"],# "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_electron_pt2", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt2"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight', 
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30',
                 'semilep_recoele30tight_Ele32',
                 "semilep_recoele30tight_tripleB_Ele30"], 
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30","Ele32",
                        "Ele30 | 4jet 3b HT330"],# "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_electron_pt2", 
                  yratio_lim=[0.4,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt3"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30'],
                 #'semilep_recoele15tight_Ele32',
                 #"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30"],#"Ele32",
                        #"Ele30 | 4jet 3b HT330"],# "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_electron_pt3", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt4"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30'],
                 #'semilep_recoele15tight_Ele32',
                 #"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30"],#,"Ele32",
                        #"Ele30 | 4jet 3b HT330"],# "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_electron_pt4", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["ElectronGood_pt4"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele30tight', 
                 'semilep_recoele30tight_Ele28',
                 'semilep_recoele30tight_Ele30', 
                 'semilep_recoele30tight_Ele28_or_Ele30'],
                 #'semilep_recoele30tight_Ele32',
                 #"semilep_recoele30tight_tripleB_Ele30"], 
                 #"semilep_recoele30tight_doubleB_tighter_Ele30",
                #"semilep_recoele30tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>30$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30"],#"Ele32",
                        #"Ele30 | 4jet 3b HT330"], # "Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele30_electron_pt4", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in multiply
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:40: RuntimeWarning: invalid value encountered in divide
#   err = np.sqrt((1/nomvalues)**2 * h_sig2 + (h_val/nomvalues**2)**2 * nom_sig2 )
# /tmp/ipykernel_64071/2718254457.py:41: RuntimeWarning: invalid value encountered in divide
#   r = np.where(nomvalues>0,h.values() / nomvalues, 1.0)
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')

# %%
hist_comparison_2(df["variables"]["nJets"]["TTH_Hto2B"]["TTH_Hto2B_2022_postEE"], 
                ['semilep_recoele15tight', 
                 'semilep_recoele15tight_Ele28',
                 'semilep_recoele15tight_Ele30', 
                 'semilep_recoele15tight_Ele28_or_Ele30'],
                 #'semilep_recoele15tight_Ele32'],
                 #"semilep_recoele15tight_tripleB_Ele30"], 
                 #"semilep_recoele15tight_doubleB_tighter_Ele30",
                #"semilep_recoele15tight_doubleB_looser_Ele30"],
                 labels=["1 tight ele $p_T>15$", "Ele28_HT150", "Ele30",
                         "Ele28_HT150 | Ele30"],#"Ele32",
                        #"Ele30 | 4jet 3b HT330"], #"Ele30 | 4jet 2b tight", "Ele30 | 4jet 2b loose"],
                  file="semilep_recoele15_njets", 
                  yratio_lim=[0.0,1.1],
                 output_folder="/work/gbonomel/ttHbb/ele_HLT_efficiency/output_dask/eff_plots")
# Out:
# /tmp/ipykernel_64071/2718254457.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axd.legend(ncol=3, fontsize='xx-small')
